# %% [markdown]
# <a href="https://colab.research.google.com/github/ParthDevpura/skills-introduction-to-github/blob/Test/hpc_lab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("hello hpc_lab")
# Out:
# hello hpc_lab

# %%
import torch
print(torch.cuda.is_available())
# Out:
# True

# %%
a = 10
b = 20

sum = a + b

print("Addition is:", sum)
# Out:
# Addition is: 30
